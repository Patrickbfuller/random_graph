# %%
from matplotlib import pyplot as plt
import numpy as np
plt.style.use('dark_background')

# %%
maxx = -1
for _ in range(100):
    hexx = np.random.randint(0,10)
    if hexx > maxx:
        maxx = hexx
''.join([str(maxx)]*6)
# Out:
# '999999'

# %%
[str(np.random.randint(0,10)) for i in range(6)]
# Out:
# ['7', '0', '4', '6', '0', '7']

# %%
hexlist = [str(np.random.randint(0,10)) for i in range(6)]
hexlist, ''.join(hexlist)
# Out:
# (['2', '0', '3', '4', '7', '9'], '203479')

# %%
d = np.random.random(100)
plt.hist(d)
# Out:
# (array([ 9., 19.,  9.,  7.,  5., 10., 10., 13., 12.,  6.]),
#  array([0.01441032, 0.11218866, 0.209967  , 0.30774535, 0.40552369,
#         0.50330203, 0.60108037, 0.69885872, 0.79663706, 0.8944154 ,
#         0.99219375]),
#  <a list of 10 Patch objects>)

# %%
plt.scatter(1,1,c=np.array([[1,0.4,0.5,0.4]]),s=100000)

# %%
rgba = [np.random.random() for _ in range(4)]
color = np.array([rgba])
plt.scatter(1,1,c=color,s=100000)

# %%
plt.figure(figsize=(15,15))
for _ in range(1000):
    a = np.random.randint(0,1000,5)
    b = np.random.randint(0,1000,5)
    rgba = [np.random.random() for _ in range(4)]
    color = np.array([rgba])
    marker = np.random.choice(['.'])
    alpha = np.random.random()**2.5
    size = np.random.exponential()**5.3
    plt.plot(a,b, alpha=alpha/1.9, linestyle=':', lw=np.random.random())

# %%
for _ in range(1000):
    a = np.random.randint(0,1000,5)
    b = np.random.randint(0,1000,5)
    rgba = [np.random.random() for _ in range(4)]
    color = np.array([rgba])
    marker = np.random.choice(['.'])
    alpha = np.random.random()**2.5
    size = np.random.exponential()**5.3
    plt.scatter(a,b, alpha=0.1, marker=marker,
               color=color, s=size)

# %%
plt.figure(figsize=(18,14))
for _ in range(1000):
    a = np.random.randint(0,1000,5)
    b = np.random.randint(0,1000,5)
    rgba = [np.random.random() for _ in range(4)]
    color = np.array([rgba])
    marker = np.random.choice(['.'])
    alpha = np.random.random()**2.5
    size = np.random.exponential()**5.3
    plt.scatter(a,b, alpha=alpha*0.5, marker=marker,
               color=color, s=size)

# %%
markers = {'.': 'point', ',': 'pixel', 'o': 'circle', 'v': 'triangle_down', '^': 'triangle_up', 
           '<': 'triangle_left', '>': 'triangle_right', '1': 'tri_down', '2': 'tri_up', '3': 'tri_left', 
           '4': 'tri_right', '8': 'octagon', 's': 'square', 'p': 'pentagon', '*': 'star', 'h': 'hexagon1', 
           'H': 'hexagon2', '+': 'plus', 'x': 'x', 'D': 'diamond', 'd': 'thin_diamond', '|': 'vline', 
           '_': 'hline', 'P': 'plus_filled', 'X': 'x_filled', 0: 'tickleft', 1: 'tickright', 2: 'tickup', 
           3: 'tickdown', 4: 'caretleft', 5: 'caretright', 6: 'caretup', 7: 'caretdown', 8: 'caretleftbase',
           9: 'caretrightbase', 10: 'caretupbase', 11: 'caretdownbase', 'None': 'nothing', None: 'nothing', 
           ' ': 'nothing', '': 'nothing'}

# %%
plt.figure(figsize=(12,12))
for _ in range(1000):
    a = np.random.randint(0,1000,5)
    b = np.random.randint(0,1000,5)
    rgba = [np.random.random() for _ in range(4)]
    color = np.array([rgba])
    marker = np.random.choice(list(markers.keys()))
    alpha = np.random.random()**2.5
    size = np.random.exponential()**5.3
    plt.scatter(a,b, alpha=0.4, marker=marker,
               color=color, s=size)

# %%
plt.figure(figsize=(22,18))
for _ in range(1000):
    a = np.random.randint(0,1000,5)
    b = np.random.randint(0,1000,5)
    hexlist = [str(np.random.randint(0,10)) for i in range(6)]
    color = '#'+''.join(hexlist)
    marker = np.random.choice(['.'])
    alpha = np.random.random()**2.5
    size = np.abs(np.random.normal())**5.3
    plt.scatter(a, b, c=color, marker=marker,
                s=20*size, alpha=alpha/1.5)

# %%
plt.figure(figsize=(22,18))
for _ in range(1000):
    a = np.random.randint(0,1000,5)
    b = np.random.randint(0,1000,5)
    hexlist = [str(np.random.randint(0,10)) for i in range(6)]
    color = '#'+''.join(hexlist)
    marker = np.random.choice(list(markers.keys()))
    alpha = np.random.random()**2.5
    size = np.random.exponential()**5.3
    plt.scatter(a, b, c=color, marker=marker,
                s=size, alpha=alpha**0.7)

# %%
plt.figure(figsize=(24,40))
for i in range(1,9):
    plt.subplot(4,2,i)
    for i in range(1000):
        a = np.random.randint(0,1000,1)
        b = np.random.randint(0,1000,1)
        rgba = [np.random.random() for _ in range(4)]
        color = np.array([rgba])
        marker = np.random.choice(['.'])
        alpha = np.random.random()**2.5
        size = np.random.exponential()**5.3
        plt.scatter(a,b, alpha=0.6, marker=marker,
                   color=color, s=size)
